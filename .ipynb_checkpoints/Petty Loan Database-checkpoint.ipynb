# %%
import pandas as pd

# %%
df=pd.read_csv('Petty Loan Database.csv')
df.head()
# Out:
#    Attribute 1  Attribute 2  Attribute 3  Attribute 4  Attribute 5  \
# 0          0.6          1.0          1.0     1.000000         1.00
# 1          0.2          1.0          1.0     0.478261         1.00
# 2          0.8          1.0          1.0     0.869565         0.75
# 3          0.4          1.0          1.0     1.000000         1.00
# 4          0.6          1.0          1.0     1.000000         1.00
#
#    Attribute 6  Attribute 7  Attribute 8  Attribute 9  Attribute 10  ...  \
# 0         0.25         0.25            1          1.0             0  ...
# 1         0.25         0.25            1          1.0             0  ...
# 2         0.25         0.25            1          1.0             0  ...
# 3         0.25         0.25            1          1.0             0  ...
# 4         0.25         0.25            1          1.0             0  ...
#
#    Attribute 52  Attribute 53  Attribute 54  Attribute 55  Attribute 56  \
# 0      0.005602      0.083344      0.091508      0.675439      0.575758
# 1      0.087092      0.119063      0.347130      0.298246      0.242424
# 2      0.072540      0.714379      0.347130      0.298246      0.242424
# 3      0.007543      0.095251      0.347130      0.298246      0.242424
# 4      0.038586      0.107157      0.347130      0.298246      0.242424
#
#    Attribute 57  Attribute 58  Attribute 59  Attribute 60  Class
# 0      0.179381      0.144174      0.618182      1.000000   Good
# 1      0.501376      0.750000      0.157576      0.503235   Good
# 2      0.501376      0.750000      0.157576      1.000000   Good
# 3      0.501376      0.750000      0.157576      0.503235   Good
# 4      0.501376      0.750000      0.157576      0.503235   Good
#
# [5 rows x 61 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le_Class=LabelEncoder()

# %%
df['Class']=le_Class.fit_transform(df['Class'])
df
# Out:
#       Attribute 1  Attribute 2  Attribute 3  Attribute 4  Attribute 5  \
# 0             0.6          1.0          1.0     1.000000         1.00
# 1             0.2          1.0          1.0     0.478261         1.00
# 2             0.8          1.0          1.0     0.869565         0.75
# 3             0.4          1.0          1.0     1.000000         1.00
# 4             0.6          1.0          1.0     1.000000         1.00
# ...           ...          ...          ...          ...          ...
# 2152          0.4          1.0          1.0     1.000000         0.25
# 2153          0.4          1.0          1.0     1.000000         1.00
# 2154          0.6          0.5          0.8     0.565217         1.00
# 2155          0.8          1.0          1.0     1.000000         0.75
# 2156          0.6          1.0          1.0     1.000000         1.00
#
#       Attribute 6  Attribute 7  Attribute 8  Attribute 9  Attribute 10  ...  \
# 0            0.25         0.25            1          1.0             0  ...
# 1            0.25         0.25            1          1.0             0  ...
# 2            0.25         0.25            1          1.0             0  ...
# 3            0.25         0.25            1          1.0             0  ...
# 4            0.25         0.25            1          1.0             0  ...
# ...           ...          ...          ...          ...           ...  ...
# 2152         0.25         0.25            1          1.0             0  ...
# 2153         0.75         0.25            1          1.0             0  ...
# 2154         0.25         0.25            0          1.0             0  ...
# 2155         1.00         0.25            1          1.0             0  ...
# 2156         1.00         0.25            1          1.0             0  ...
#
#       Attribute 52  Attribute 53  Attribute 54  Attribute 55  Attribute 56  \
# 0         0.005602      0.083344      0.091508      0.675439      0.575758
# 1         0.087092      0.119063      0.347130      0.298246      0.242424
# 2         0.072540      0.714379      0.347130      0.298246      0.242424
# 3         0.007543      0.095251      0.347130      0.298246      0.242424
# 4         0.038586      0.107157      0.347130      0.298246      0.242424
# ...            ...           ...           ...           ...           ...
# 2152      0.009483      0.023813      0.347130      0.298246      0.242424
# 2153      0.150149      0.250033      0.347130      0.298246      0.242424
# 2154      1.000000      1.000000      0.091508      0.675439      0.575758
# 2155      0.021609      0.130970      0.032503      0.736842      0.060606
# 2156      0.004875      0.000000      0.245739      0.605263      0.575758
#
#       Attribute 57  Attribute 58  Attribute 59  Attribute 60  Class
# 0         0.179381      0.144174      0.618182      1.000000      1
# 1         0.501376      0.750000      0.157576      0.503235      1
# 2         0.501376      0.750000      0.157576      1.000000      1
# 3         0.501376      0.750000      0.157576      0.503235      1
# 4         0.501376      0.750000      0.157576      0.503235      1
# ...            ...           ...           ...           ...    ...
# 2152      0.501376      0.750000      0.157576      0.503235      0
# 2153      0.501376      0.750000      0.157576      1.000000      0
# 2154      0.179381      0.144174      0.618182      0.503235      0
# 2155      0.083349      0.208286      0.721212      0.000000      0
# 2156      0.499860      0.509930      0.324242      0.000000      0
#
# [2157 rows x 61 columns]

# %%
from sklearn.feature_selection import VarianceThreshold
var_thres=VarianceThreshold(threshold=0)
var_thres.fit(df)
# Out:
# VarianceThreshold(threshold=0)

# %%
var_thres.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True])

# %%
df.columns[var_thres.get_support()]
# Out:
# Index(['Attribute 1', 'Attribute 2', 'Attribute 3', 'Attribute 4',
#        'Attribute 5', 'Attribute 6', 'Attribute 7', 'Attribute 8',
#        'Attribute 9', 'Attribute 10', 'Attribute 11', 'Attribute 12',
#        'Attribute 13', 'Attribute 14', 'Attribute 15', 'Attribute 16',
#        'Attribute 17', 'Attribute 18', 'Attribute 19', 'Attribute 20',
#        'Attribute 21', 'Attribute 22', 'Attribute 23', 'Attribute 24',
#        'Attribute 25', 'Attribute 26', 'Attribute 27', 'Attribute 28',
#        'Attribute 29', 'Attribute 30', 'Attribute 31', 'Attribute 32',
#        'Attribute 33', 'Attribute 34', 'Attribute 35', 'Attribute 36',
#        'Attribute 37', 'Attribute 38', 'Attribute 39', 'Attribute 40',
#        'Attribute 41', 'Attribute 42', 'Attribute 43', 'Attribute 44',
#        'Attribute 45', 'Attribute 46', 'Attribute 47', 'Attribute 48',
#        'Attribute 49', 'Attribute 50', 'Attribute 51', 'Attribute 52',
#        'Attribute 53', 'Attribute 54', 'Attribute 55', 'Attribute 56',
#        'Attribute 57', 'Attribute 58', 'Attribute 59', 'Attribute 60',
#        'Class'],
#       dtype='object')

# %%
constant_columns = [column for column in df.columns
                    if column not in df.columns[var_thres.get_support()]]

print(len(constant_columns))
# Out:
# 0

# %% [markdown]
# # Pearson Correlation

# %%
from sklearn.datasets import load_boston
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.corr()
# Out:
#               Attribute 1  Attribute 2  Attribute 3  Attribute 4  Attribute 5  \
# Attribute 1      1.000000    -0.027911    -0.025202     0.057680    -0.042566
# Attribute 2     -0.027911     1.000000     0.080222     0.106116     0.067964
# Attribute 3     -0.025202     0.080222     1.000000    -0.015363     0.050346
# Attribute 4      0.057680     0.106116    -0.015363     1.000000     0.028845
# Attribute 5     -0.042566     0.067964     0.050346     0.028845     1.000000
# ...                   ...          ...          ...          ...          ...
# Attribute 57     0.010402    -0.001631     0.049727    -0.025185    -0.044215
# Attribute 58    -0.035754    -0.011591     0.080761     0.012956     0.063860
# Attribute 59     0.064088    -0.007821    -0.073888    -0.020409    -0.278922
# Attribute 60     0.011884    -0.029687    -0.012154    -0.041763    -0.088035
# Class           -0.030853     0.066404     0.009783     0.043616    -0.050205
#
#               Attribute 6  Attribute 7  Attribute 8  Attribute 9  \
# Attribute 1      0.185138     0.095582    -0.034903    -0.031579
# Attribute 2     -0.033968    -0.010835     0.014848    -0.022779
# Attribute 3     -0.027901     0.002498     0.015158     0.036064
# Attribute 4     -0.067322    -0.004994     0.087643    -0.004791
# Attribute 5     -0.339791    -0.271877     0.269779    -0.013496
# ...                   ...          ...          ...          ...
# Attribute 57     0.131400     0.046030    -0.050825     0.200171
# Attribute 58     0.001974    -0.055041     0.031340     0.240282
# Attribute 59     0.182568     0.195840    -0.132487    -0.131820
# Attribute 60     0.129895     0.103188    -0.013739     0.066491
# Class            0.031579     0.016438    -0.034955     0.008348
#
#               Attribute 10  ...  Attribute 52  Attribute 53  Attribute 54  \
# Attribute 1      -0.033621  ...     -0.016219     -0.022840      0.017056
# Attribute 2       0.009701  ...      0.011997      0.020184     -0.021924
# Attribute 3      -0.001452  ...      0.081301      0.085048      0.030776
# Attribute 4       0.020980  ...     -0.042948     -0.021162     -0.025956
# Attribute 5      -0.095228  ...      0.135084      0.192557      0.030610
# ...                    ...  ...           ...           ...           ...
# Attribute 57     -0.040210  ...     -0.026646      0.071942      0.910956
# Attribute 58     -0.009826  ...     -0.054685      0.061842      0.833769
# Attribute 59      0.056676  ...     -0.000862     -0.068194     -0.541316
# Attribute 60     -0.020550  ...      0.006274      0.035239      0.011475
# Class             0.044240  ...     -0.027930      0.036978      0.069591
#
#               Attribute 55  Attribute 56  Attribute 57  Attribute 58  \
# Attribute 1       0.042259      0.063914      0.010402     -0.035754
# Attribute 2       0.019550      0.003210     -0.001631     -0.011591
# Attribute 3      -0.048376     -0.052668      0.049727      0.080761
# Attribute 4      -0.020446     -0.029978     -0.025185      0.012956
# Attribute 5      -0.166263     -0.018152     -0.044215      0.063860
# ...                    ...           ...           ...           ...
# Attribute 57     -0.397130     -0.234948      1.000000      0.851904
# Attribute 58     -0.681010     -0.581427      0.851904      1.000000
# Attribute 59      0.683256      0.163720     -0.516837     -0.644302
# Attribute 60      0.032346     -0.017362      0.057532      0.016290
# Class            -0.077568     -0.141513      0.109378      0.146241
#
#               Attribute 59  Attribute 60     Class
# Attribute 1       0.064088      0.011884 -0.030853
# Attribute 2      -0.007821     -0.029687  0.066404
# Attribute 3      -0.073888     -0.012154  0.009783
# Attribute 4      -0.020409     -0.041763  0.043616
# Attribute 5      -0.278922     -0.088035 -0.050205
# ...                    ...           ...       ...
# Attribute 57     -0.516837      0.057532  0.109378
# Attribute 58     -0.644302      0.016290  0.146241
# Attribute 59      1.000000      0.048848 -0.101711
# Attribute 60      0.048848      1.000000 -0.017903
# Class            -0.101711     -0.017903  1.000000
#
# [61 rows x 61 columns]

# %%
import seaborn as sns
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if (corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(df, 0.85)
len(set(corr_features))
# Out:
# 8

# %%
corr_features
# Out:
# {'Attribute 12',
#  'Attribute 18',
#  'Attribute 22',
#  'Attribute 23',
#  'Attribute 26',
#  'Attribute 29',
#  'Attribute 57',
#  'Attribute 58'}

# %%
for col in corr_features:
    df.drop(col,axis=1,inplace=True)

# %%
df.head()
# Out:
#    Attribute 1  Attribute 2  Attribute 3  Attribute 4  Attribute 5  \
# 0          0.6          1.0          1.0     1.000000         1.00
# 1          0.2          1.0          1.0     0.478261         1.00
# 2          0.8          1.0          1.0     0.869565         0.75
# 3          0.4          1.0          1.0     1.000000         1.00
# 4          0.6          1.0          1.0     1.000000         1.00
#
#    Attribute 6  Attribute 7  Attribute 8  Attribute 9  Attribute 10  ...  \
# 0         0.25         0.25            1          1.0             0  ...
# 1         0.25         0.25            1          1.0             0  ...
# 2         0.25         0.25            1          1.0             0  ...
# 3         0.25         0.25            1          1.0             0  ...
# 4         0.25         0.25            1          1.0             0  ...
#
#    Attribute 50  Attribute 51  Attribute 52  Attribute 53  Attribute 54  \
# 0      0.967265          0.25      0.005602      0.083344      0.091508
# 1      0.961151          0.50      0.087092      0.119063      0.347130
# 2      0.856022          0.50      0.072540      0.714379      0.347130
# 3      0.969160          1.00      0.007543      0.095251      0.347130
# 4      0.958681          0.50      0.038586      0.107157      0.347130
#
#    Attribute 55  Attribute 56  Attribute 59  Attribute 60  Class
# 0      0.675439      0.575758      0.618182      1.000000      1
# 1      0.298246      0.242424      0.157576      0.503235      1
# 2      0.298246      0.242424      0.157576      1.000000      1
# 3      0.298246      0.242424      0.157576      0.503235      1
# 4      0.298246      0.242424      0.157576      0.503235      1
#
# [5 rows x 53 columns]
